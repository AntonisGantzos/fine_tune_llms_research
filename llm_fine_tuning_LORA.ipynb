# %% [markdown]
# ## LORA training/testing pipeline exploration

# %% [markdown]
# # Step 1 : Load data (master_clauses file from CUAD)
#
# Dataset Description Summarized :
#
# 1. Columns NOT ending in "Answer" (Context Columns)
# - Role: These columns contain the text context (the actual excerpt or "clause") extracted from the contract.
# - Content: A string of text directly from the contract that is responsive to a specific category.
# - Purpose: This serves as the "evidence" or the "source passage" that justifies a specific determination.
# - Handling of Omissions: If parts of the text are irrelevant, they may be replaced with <omitted>.
#
# 2. Columns ending in "Answer" (Label Columns)
# - Role: These columns contain the derived human-input answers based on the text context found in the corresponding Context column.
# - Content:
# - For "Yes/No" Categories (33 types): The value is "Yes" if the clause exists, or "No" if no string was found. (e.g., Termination for Convenience).
# - For Extraction Categories (8 types): The value is a normalized string representing a specific entity, date, or number (e.g., converting "8th day of May 2014" in the text to "5/8/2014" in the Answer column).
# - Purpose: This is the "ground truth" or "label" for the machine learning task.

# %%
import pandas as pd
import json
from pathlib import Path
import csv
import re
from sklearn.model_selection import train_test_split

# %%
CUAD_PATH = Path('data/cuad') 
MASTER_CLAUSES_PATH = CUAD_PATH/'master_clauses_cleaned.csv' 

try:
    # Read the file manually using the CSV module first to handle inconsistencies
    data = []
    with open(MASTER_CLAUSES_PATH, 'r', encoding='utf-8', errors='replace') as f:
        # Use csv.Sniffer to deduce format if possible, or enforce standard strictness
        reader = csv.DictReader(f) 
        for i, row in enumerate(reader):
            data.append(row)

    # Convert the list of dicts to a DataFrame
    df = pd.DataFrame(data)

    print(f"Data Loaded Successfully via CSV module.")
    print(f"Total Contracts: {len(df)}")
    print(df.head(3))

except Exception as e:
    print(f"Error: {e}")
# Out:
# Data Loaded Successfully via CSV module.
# Total Contracts: 545
#                                             Filename Document Name  \
# 0  CybergyHoldingsInc2014052010QEX10278605784EX10...            MA
# 1  EuromediaHoldingsCorp2007021510SB12GEX10B01525...       July 11
# 2  FulucaiProductionsLtd2013122310QEX1098368347EX...   November 15
#
#   Document Name-Answer Parties Parties-Answer Agreement Date  \
# 0  8th day of May 2014   May 8           2014           5814
# 1                 2006   71106        July 11           2006
# 2                 2012  111512    November 15           2012
#
#                                Agreement Date-Answer  \
# 0  This agreement shall begin upon the date of it...
# 1                                              71106
# 2                                             111512
#
#                                       Effective Date  \
# 0
# 1  The term of this Agreement the Initial Term sh...
# 2
#
#                                Effective Date-Answer  \
# 0  This agreement shall begin upon the date of it...
# 1  unless earlier terminated in accordance with t...
# 2
#
#               Expiration Date  ...    Liquidated Damages-Answer  \
# 0                      123114  ...                           No
# 1  shall terminate on June 30  ...                           No
# 2      License Term Perpetual  ...  Satellite x Pay Terrestrial
#
#   Warranty Duration                           Warranty Duration-Answer  \
# 0                                                                   No
# 1                                                                   No
# 2             Cable  Satellite x Direct Satellite IP Distribution S...
#
#                                            Insurance  \
# 0
# 1
# 2  Producer further grants to ConvergTV the right...
#
#                Insurance-Answer  \
# 0                            No
# 1                            No
# 2  at its sole cost and expense
#
#                                  Covenant Not To Sue  \
# 0
# 1  Notwithstanding any other provision of this Ag...
# 2          new and different versions of the Program
#
#             Covenant Not To Sue-Answer  \
# 0                                   No
# 1  Rogers may terminate this Agreement
# 2              create foreign language
#
#                              Third Party Beneficiary  \
# 0
# 1                                        at any time
# 2  subtitled or translated versions of the Progra...
#
#   Third Party Beneficiary-Answer;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;  \
# 0                                                 No
# 1  upon sixty 60 days prior written notice to Lic...
# 2                                     including NTCS
#
#
# 0
# 1
# 2
#
# [3 rows x 84 columns]

# %%
df.head(3)
# Out:
#                                             Filename Document Name  \
# 0  CybergyHoldingsInc2014052010QEX10278605784EX10...            MA
# 1  EuromediaHoldingsCorp2007021510SB12GEX10B01525...       July 11
# 2  FulucaiProductionsLtd2013122310QEX1098368347EX...   November 15
#
#   Document Name-Answer Parties Parties-Answer Agreement Date  \
# 0  8th day of May 2014   May 8           2014           5814
# 1                 2006   71106        July 11           2006
# 2                 2012  111512    November 15           2012
#
#                                Agreement Date-Answer  \
# 0  This agreement shall begin upon the date of it...
# 1                                              71106
# 2                                             111512
#
#                                       Effective Date  \
# 0
# 1  The term of this Agreement the Initial Term sh...
# 2
#
#                                Effective Date-Answer  \
# 0  This agreement shall begin upon the date of it...
# 1  unless earlier terminated in accordance with t...
# 2
#
#               Expiration Date  ...    Liquidated Damages-Answer  \
# 0                      123114  ...                           No
# 1  shall terminate on June 30  ...                           No
# 2      License Term Perpetual  ...  Satellite x Pay Terrestrial
#
#   Warranty Duration                           Warranty Duration-Answer  \
# 0                                                                   No
# 1                                                                   No
# 2             Cable  Satellite x Direct Satellite IP Distribution S...
#
#                                            Insurance  \
# 0
# 1
# 2  Producer further grants to ConvergTV the right...
#
#                Insurance-Answer  \
# 0                            No
# 1                            No
# 2  at its sole cost and expense
#
#                                  Covenant Not To Sue  \
# 0
# 1  Notwithstanding any other provision of this Ag...
# 2          new and different versions of the Program
#
#             Covenant Not To Sue-Answer  \
# 0                                   No
# 1  Rogers may terminate this Agreement
# 2              create foreign language
#
#                              Third Party Beneficiary  \
# 0
# 1                                        at any time
# 2  subtitled or translated versions of the Progra...
#
#   Third Party Beneficiary-Answer;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;  \
# 0                                                 No
# 1  upon sixty 60 days prior written notice to Lic...
# 2                                     including NTCS
#
#
# 0
# 1
# 2
#
# [3 rows x 84 columns]

# %%
def clean_text(text):
    if pd.isna(text):
        return ""
    text = str(text)
    # Remove special characters but keep spaces
    return re.sub(r'[^a-zA-Z0-9\s]', '', text)

# Clean column names
df.columns = [clean_text(col).strip() for col in df.columns]
for col in df.columns:
    print(col)
# Out:
# Filename
# Document Name
# Document NameAnswer
# Parties
# PartiesAnswer
# Agreement Date
# Agreement DateAnswer
# Effective Date
# Effective DateAnswer
# Expiration Date
# Expiration DateAnswer
# Renewal Term
# Renewal TermAnswer
# Notice Period To Terminate Renewal
# Notice Period To Terminate Renewal Answer
# Governing Law
# Governing LawAnswer
# Most Favored Nation
# Most Favored NationAnswer
# Competitive Restriction Exception
# Competitive Restriction ExceptionAnswer
# NonCompete
# NonCompeteAnswer
# Exclusivity
# ExclusivityAnswer
# NoSolicit Of Customers
# NoSolicit Of CustomersAnswer
# NoSolicit Of Employees
# NoSolicit Of EmployeesAnswer
# NonDisparagement
# NonDisparagementAnswer
# Termination For Convenience
# Termination For ConvenienceAnswer
# RofrRofoRofn
# RofrRofoRofnAnswer
# Change Of Control
# Change Of ControlAnswer
# AntiAssignment
# AntiAssignmentAnswer
# RevenueProfit Sharing
# RevenueProfit SharingAnswer
# Price Restrictions
# Price RestrictionsAnswer
# Minimum Commitment
# Minimum CommitmentAnswer
# Volume Restriction
# Volume RestrictionAnswer
# Ip Ownership Assignment
# Ip Ownership AssignmentAnswer
# Joint Ip Ownership
# Joint Ip OwnershipAnswer
# License Grant
# License GrantAnswer
# NonTransferable License
# NonTransferable LicenseAnswer
# Affiliate LicenseLicensor
# Affiliate LicenseLicensorAnswer
# Affiliate LicenseLicensee
# Affiliate LicenseLicenseeAnswer
# UnlimitedAllYouCanEatLicense
# UnlimitedAllYouCanEatLicenseAnswer
# Irrevocable Or Perpetual License
# Irrevocable Or Perpetual LicenseAnswer
# Source Code Escrow
# Source Code EscrowAnswer
# PostTermination Services
# PostTermination ServicesAnswer
# Audit Rights
# Audit RightsAnswer
# Uncapped Liability
# Uncapped LiabilityAnswer
# Cap On Liability
# Cap On LiabilityAnswer
# Liquidated Damages
# Liquidated DamagesAnswer
# Warranty Duration
# Warranty DurationAnswer
# Insurance
# InsuranceAnswer
# Covenant Not To Sue
# Covenant Not To SueAnswer
# Third Party Beneficiary
# Third Party BeneficiaryAnswer

# %%
new_columns = {}
for col in df.columns:
    print(f"Processing column: '{col}'")
    if "Answer" in col:
            # Remove "Answer" from the string and append "_Answer" at the end
            new_columns[col] = f"{col.replace('Answer', '').strip()}_Answer"

df = df.rename(columns=new_columns)
# Out:
# Processing column: 'Filename'
# Processing column: 'Document Name'
# Processing column: 'Document NameAnswer'
# Processing column: 'Parties'
# Processing column: 'PartiesAnswer'
# Processing column: 'Agreement Date'
# Processing column: 'Agreement DateAnswer'
# Processing column: 'Effective Date'
# Processing column: 'Effective DateAnswer'
# Processing column: 'Expiration Date'
# Processing column: 'Expiration DateAnswer'
# Processing column: 'Renewal Term'
# Processing column: 'Renewal TermAnswer'
# Processing column: 'Notice Period To Terminate Renewal'
# Processing column: 'Notice Period To Terminate Renewal Answer'
# Processing column: 'Governing Law'
# Processing column: 'Governing LawAnswer'
# Processing column: 'Most Favored Nation'
# Processing column: 'Most Favored NationAnswer'
# Processing column: 'Competitive Restriction Exception'
# Processing column: 'Competitive Restriction ExceptionAnswer'
# Processing column: 'NonCompete'
# Processing column: 'NonCompeteAnswer'
# Processing column: 'Exclusivity'
# Processing column: 'ExclusivityAnswer'
# Processing column: 'NoSolicit Of Customers'
# Processing column: 'NoSolicit Of CustomersAnswer'
# Processing column: 'NoSolicit Of Employees'
# Processing column: 'NoSolicit Of EmployeesAnswer'
# Processing column: 'NonDisparagement'
# Processing column: 'NonDisparagementAnswer'
# Processing column: 'Termination For Convenience'
# Processing column: 'Termination For ConvenienceAnswer'
# Processing column: 'RofrRofoRofn'
# Processing column: 'RofrRofoRofnAnswer'
# Processing column: 'Change Of Control'
# Processing column: 'Change Of ControlAnswer'
# Processing column: 'AntiAssignment'
# Processing column: 'AntiAssignmentAnswer'
# Processing column: 'RevenueProfit Sharing'
# Processing column: 'RevenueProfit SharingAnswer'
# Processing column: 'Price Restrictions'
# Processing column: 'Price RestrictionsAnswer'
# Processing column: 'Minimum Commitment'
# Processing column: 'Minimum CommitmentAnswer'
# Processing column: 'Volume Restriction'
# Processing column: 'Volume RestrictionAnswer'
# Processing column: 'Ip Ownership Assignment'
# Processing column: 'Ip Ownership AssignmentAnswer'
# Processing column: 'Joint Ip Ownership'
# Processing column: 'Joint Ip OwnershipAnswer'
# Processing column: 'License Grant'
# Processing column: 'License GrantAnswer'
# Processing column: 'NonTransferable License'
# Processing column: 'NonTransferable LicenseAnswer'
# Processing column: 'Affiliate LicenseLicensor'
# Processing column: 'Affiliate LicenseLicensorAnswer'
# Processing column: 'Affiliate LicenseLicensee'
# Processing column: 'Affiliate LicenseLicenseeAnswer'
# Processing column: 'UnlimitedAllYouCanEatLicense'
# Processing column: 'UnlimitedAllYouCanEatLicenseAnswer'
# Processing column: 'Irrevocable Or Perpetual License'
# Processing column: 'Irrevocable Or Perpetual LicenseAnswer'
# Processing column: 'Source Code Escrow'
# Processing column: 'Source Code EscrowAnswer'
# Processing column: 'PostTermination Services'
# Processing column: 'PostTermination ServicesAnswer'
# Processing column: 'Audit Rights'
# Processing column: 'Audit RightsAnswer'
# Processing column: 'Uncapped Liability'
# Processing column: 'Uncapped LiabilityAnswer'
# Processing column: 'Cap On Liability'
# Processing column: 'Cap On LiabilityAnswer'
# Processing column: 'Liquidated Damages'
# Processing column: 'Liquidated DamagesAnswer'
# Processing column: 'Warranty Duration'
# Processing column: 'Warranty DurationAnswer'
# Processing column: 'Insurance'
# Processing column: 'InsuranceAnswer'
# Processing column: 'Covenant Not To Sue'
# Processing column: 'Covenant Not To SueAnswer'
# Processing column: 'Third Party Beneficiary'
# Processing column: 'Third Party BeneficiaryAnswer'
# Processing column: ''

# %%
for col in df.columns:
    print(col)
# Out:
# Filename
# Document Name
# Document Name_Answer
# Parties
# Parties_Answer
# Agreement Date
# Agreement Date_Answer
# Effective Date
# Effective Date_Answer
# Expiration Date
# Expiration Date_Answer
# Renewal Term
# Renewal Term_Answer
# Notice Period To Terminate Renewal
# Notice Period To Terminate Renewal_Answer
# Governing Law
# Governing Law_Answer
# Most Favored Nation
# Most Favored Nation_Answer
# Competitive Restriction Exception
# Competitive Restriction Exception_Answer
# NonCompete
# NonCompete_Answer
# Exclusivity
# Exclusivity_Answer
# NoSolicit Of Customers
# NoSolicit Of Customers_Answer
# NoSolicit Of Employees
# NoSolicit Of Employees_Answer
# NonDisparagement
# NonDisparagement_Answer
# Termination For Convenience
# Termination For Convenience_Answer
# RofrRofoRofn
# RofrRofoRofn_Answer
# Change Of Control
# Change Of Control_Answer
# AntiAssignment
# AntiAssignment_Answer
# RevenueProfit Sharing
# RevenueProfit Sharing_Answer
# Price Restrictions
# Price Restrictions_Answer
# Minimum Commitment
# Minimum Commitment_Answer
# Volume Restriction
# Volume Restriction_Answer
# Ip Ownership Assignment
# Ip Ownership Assignment_Answer
# Joint Ip Ownership
# Joint Ip Ownership_Answer
# License Grant
# License Grant_Answer
# NonTransferable License
# NonTransferable License_Answer
# Affiliate LicenseLicensor
# Affiliate LicenseLicensor_Answer
# Affiliate LicenseLicensee
# Affiliate LicenseLicensee_Answer
# UnlimitedAllYouCanEatLicense
# UnlimitedAllYouCanEatLicense_Answer
# Irrevocable Or Perpetual License
# Irrevocable Or Perpetual License_Answer
# Source Code Escrow
# Source Code Escrow_Answer
# PostTermination Services
# PostTermination Services_Answer
# Audit Rights
# Audit Rights_Answer
# Uncapped Liability
# Uncapped Liability_Answer
# Cap On Liability
# Cap On Liability_Answer
# Liquidated Damages
# Liquidated Damages_Answer
# Warranty Duration
# Warranty Duration_Answer
# Insurance
# Insurance_Answer
# Covenant Not To Sue
# Covenant Not To Sue_Answer
# Third Party Beneficiary
# Third Party Beneficiary_Answer

# %%
def save_jsonl(data, filename):
    with open(filename, 'w') as f:
        for entry in data:
            f.write(json.dumps(entry) + '\n')

# %%
formatted_rows = []

for index, row in df.iterrows():
    contract_text = row["Parties"]  
    # NOTE: Using 'Parties' column often contains the full text in some versions, 
    # or you map specific columns. Per your readme, 'master_clauses.csv' 
    # has text context. Let's assume a generic extraction logic here.
    # In CUAD master_clauses, the first column is filename, others are [Category] Answer.
    # We actually need the 'Text Context' usually found in specific columns or the raw txt.
    # If using master_clauses.csv heavily, we iterate strictly over the Answer columns.

    # SIMPLIFIED LOGIC based on your `data_roles_cuad.md` strategy:
    # Iterate over all 41 categories
    for col_name in df.columns:
        if "Answer" in col_name:
            category = col_name.replace("_Answer", "")
            answer = row[col_name]
            
            # Skip empty answers if you want a denser model, 
            # OR keep "No" answers to train negative detection (Recommended in your notes).
            if pd.isna(answer) or str(answer).strip() == "":
                continue
            
            print(f"Processing row {index}, category: {category}, answer: {answer}")
            # Construct Entry
            formatted_rows.append({
                "instruction": f"Extract the {category} from the contract text. Return in JSON format.",
                "category": category,
                "input": json.dumps({category: str(row.get(f"{category}", ""))}), # Should be the context snippet
                "output": json.dumps({category: answer})
            })

# Split Data
train_data, val_data = train_test_split(formatted_rows, test_size=0.1, random_state=42)
# Out:
# Processing row 0, category: Document Name, answer: 8th day of May 2014
# Processing row 0, category: Parties, answer: 2014
# Processing row 0, category: Agreement Date, answer: This agreement shall begin upon the date of its execution by MA and acceptance in writing by Company
# Processing row 0, category: Effective Date, answer: This agreement shall begin upon the date of its execution by MA and acceptance in writing by Company and shall remain in effect until the end of the current calendar year and shall be automatically renewed for successive one 1 year periods unless otherwise terminated according to the cancellation or termination provisions contained in paragraph 18 of this Agreement
# Processing row 0, category: Expiration Date, answer: This agreement shall begin upon the date of its execution by MA and acceptance in writing by Company and shall remain in effect until the end of the current calendar year and shall be automatically renewed for successive one 1 year periods unless otherwise terminated according to the cancellation or termination provisions contained in paragraph 18 of this Agreement
# Processing row 0, category: Renewal Term, answer: This Agreement may be terminated by either party at the expiration of its term or any renewal term upon thirty 30 days written notice to the other party
# Processing row 0, category: Notice Period To Terminate Renewal, answer: This Agreement is accepted by Company in the State of Nevada and shall be governed by and construed in accordance with the laws thereof
# Processing row 0, category: Governing Law, answer: Nevada
# Processing row 0, category: Most Favored Nation, answer: No
# Processing row 0, category: Competitive Restriction Exception, answer: No
# Processing row 0, category: NonCompete, answer: No
# Processing row 0, category: Exclusivity, answer: No
# Processing row 0, category: NoSolicit Of Customers, answer: No
# Processing row 0, category: NoSolicit Of Employees, answer: No
# Processing row 0, category: NonDisparagement, answer: nor regulate the manner in which MA shall operate its business
# Processing row 0, category: Termination For Convenience, answer: goodwill and reputation of Company and its affiliatesomitted
# Processing row 0, category: RevenueProfit Sharing, answer: MA may not assign
# Processing row 0, category: Price Restrictions, answer: lease or otherwise transfer in whole or in party any of the rights granted pursuant to this Agreement without prior written approval of Company
# Processing row 0, category: Ip Ownership Assignment, answer: INITIAL ORDER COMMITMENT MA commits to purchase a minimum of 100 Units in aggregate within the Territory within the first six months of term of this Agreement
# Processing row 0, category: Affiliate LicenseLicensor, answer: Company hereby grants MA
# Processing row 0, category: Affiliate LicenseLicensee, answer: the right to use Company andor Company trade names
# Processing row 0, category: UnlimitedAllYouCanEatLicense, answer: Subject to the terms and conditions of this Agreement
# Processing row 0, category: Irrevocable Or Perpetual License, answer: market and sell to corporate users
# Processing row 0, category: Source Code Escrow, answer: soft skills and communication purposes only
# Processing row 0, category: PostTermination Services, answer: and not for use in a data center environment for multiple users Clients
# Processing row 0, category: Audit Rights, answer: the Technology listed in Schedule A of this Agreement
# Processing row 0, category: Uncapped Liability, answer: providing MA meets the criteria required for delivering services according to Schedule A
# Processing row 0, category: Cap On Liability, answer: Yes
# Processing row 0, category: Liquidated Damages, answer: No
# Processing row 0, category: Warranty Duration, answer: No
# Processing row 0, category: Insurance, answer: No
# Processing row 0, category: Covenant Not To Sue, answer: No
# Processing row 0, category: Third Party Beneficiary, answer: No
# Processing row 1, category: Document Name, answer: 2006
# Processing row 1, category: Parties, answer: July 11
# Processing row 1, category: Agreement Date, answer: 71106
# Processing row 1, category: Effective Date, answer: unless earlier terminated in accordance with this Agreement
# Processing row 1, category: Expiration Date, answer: 2010
# Processing row 1, category: Renewal Term, answer: At Rogers option
# Processing row 1, category: Notice Period To Terminate Renewal, answer: 2 years
# Processing row 1, category: Governing Law, answer: if
# Processing row 1, category: Most Favored Nation, answer: as applicable
# Processing row 1, category: Competitive Restriction Exception, answer: such continued distribution and exhibition shall be governed by the terms of this Agreement in effect at the time of expiry
# Processing row 1, category: NonCompete, answer: on sixty 60 days prior written notice
# Processing row 1, category: Exclusivity, answer: as so extended
# Processing row 1, category: NoSolicit Of Customers, answer: This Agreement is subject to all laws
# Processing row 1, category: NoSolicit Of Employees, answer: license conditions and decisions of the Canadian Radiotelevision and Telecommunications Commission CRTC municipal
# Processing row 1, category: NonDisparagement, answer: and which are now in force or hereafter adopted Applicable Law
# Processing row 1, category: Termination For Convenience, answer: Ontario
# Processing row 1, category: RofrRofoRofn, answer: In the event that Licensor grants to another VOD or PayPerView PPV service provider in the US or the Territory the right to distribute or exhibit any Licensed Program on an earlier availability date
# Processing row 1, category: Change Of Control, answer: on the terms provided herein
# Processing row 1, category: AntiAssignment, answer: or has entered
# Processing row 1, category: RevenueProfit Sharing, answer: understandings or arrangements
# Processing row 1, category: Price Restrictions, answer: whether formal or informal
# Processing row 1, category: Minimum Commitment, answer: or whether on a longterm basis or shortterm basis with a third party for the distribution and exhibition of Licensed Programs in the US or the Territory on a VOD basis
# Processing row 1, category: Volume Restriction, answer: on terms including
# Processing row 1, category: Ip Ownership Assignment, answer: license fees
# Processing row 1, category: Joint Ip Ownership, answer: encoding fees and obligations
# Processing row 1, category: License Grant, answer: then Rogers has the right to incorporate
# Processing row 1, category: NonTransferable License, answer: as the case may be
# Processing row 1, category: Affiliate LicenseLicensor, answer: effective as of the date on which such term or terms were accorded to the third party and for the balance of the period such term or terms are applicable to such third party
# Processing row 1, category: Affiliate LicenseLicensee, answer: no later than February 28 in each year
# Processing row 1, category: UnlimitedAllYouCanEatLicense, answer: or a certificate of the auditors of Licensor
# Processing row 1, category: Irrevocable Or Perpetual License, answer: during the immediately preceding calendar year
# Processing row 1, category: Source Code Escrow, answer: if it did enter into such agreements
# Processing row 1, category: PostTermination Services, answer: Yes
# Processing row 1, category: Audit Rights, answer: No
# Processing row 1, category: Uncapped Liability, answer: No
# Processing row 1, category: Cap On Liability, answer: No
# Processing row 1, category: Liquidated Damages, answer: No
# Processing row 1, category: Warranty Duration, answer: No
# Processing row 1, category: Insurance, answer: No
# Processing row 1, category: Covenant Not To Sue, answer: Rogers may terminate this Agreement
# Processing row 1, category: Third Party Beneficiary, answer: upon sixty 60 days prior written notice to Licensor
# Processing row 2, category: Document Name, answer: 2012
# Processing row 2, category: Parties, answer: November 15
# Processing row 2, category: Agreement Date, answer: 111512
# Processing row 2, category: Expiration Date, answer: unlimited runs x Other 2 years Commencing November 15
# Processing row 2, category: Renewal Term, answer: perpetual
# Processing row 2, category: Governing Law, answer: All questions with respect to the construction of this Agreement
# Processing row 2, category: Most Favored Nation, answer: shall be governed by the laws of the State of Florida
# Processing row 2, category: NoSolicit Of Customers, answer: During the License Term which is identified in the Deal Terms
# Processing row 2, category: NoSolicit Of Employees, answer: including those in Section 1
# Processing row 2, category: NonDisparagement, answer: Yes
# Processing row 2, category: Termination For Convenience, answer: No
# Processing row 2, category: RofrRofoRofn, answer: No
# Processing row 2, category: Change Of Control, answer: No
# Processing row 2, category: AntiAssignment, answer: No
# Processing row 2, category: RevenueProfit Sharing, answer: No
# Processing row 2, category: Price Restrictions, answer: No
# Processing row 2, category: Minimum Commitment, answer: No
# Processing row 2, category: Volume Restriction, answer: The revenue share for the Program is stated in Exhibit B
# Processing row 2, category: Affiliate LicenseLicensee, answer: Producer further grants to ConvergTV the right and license to Distribute and reDistribute
# Processing row 2, category: UnlimitedAllYouCanEatLicense, answer: the Program at such dates and times as are determined by ConvergTV in its sole discretion
# Processing row 2, category: Irrevocable Or Perpetual License, answer: Producer hereby grants to ConvergTV a right and license to Distribute the program
# Processing row 2, category: Source Code Escrow, answer: for unlimited runs for the License Term through ConvergTV channels andor other distribution outlets
# Processing row 2, category: PostTermination Services, answer: Licensed Rights to ConvergTV and ConvergTV Channels andor Distribution Outlets x All
# Processing row 2, category: Audit Rights, answer: short wave
# Processing row 2, category: Uncapped Liability, answer: fiber optic x Alternative
# Processing row 2, category: Cap On Liability, answer: Content Distribution NetworksCompany Servers x Full Television Broadcast Rights x Free Terrestrial
# Processing row 2, category: Liquidated Damages, answer: Satellite x Pay Terrestrial
# Processing row 2, category: Warranty Duration, answer: Satellite x Direct Satellite IP Distribution Systems
# Processing row 2, category: Insurance, answer: at its sole cost and expense
# Processing row 2, category: Covenant Not To Sue, answer: create foreign language
# Processing row 2, category: Third Party Beneficiary, answer: including NTCS
# Processing row 3, category: Document Name, answer: Feb 10
# Processing row 3, category: Parties, answer: 21014
# Processing row 3, category: Agreement Date, answer: 2014
# Processing row 3, category: Effective Date, answer: The initial term of this Agreement commences as of the Effective Date and
# Processing row 3, category: Expiration Date, answer: shall continue until five 5 years following the Effective Date the Initial Term
# Processing row 3, category: Renewal Term, answer: Thereafter
# Processing row 3, category: Notice Period To Terminate Renewal, answer: together with the Initial Term
# Processing row 3, category: Governing Law, answer: 3 years
# Processing row 3, category: Most Favored Nation, answer: this Agreement shall renew automatically for one 1 additional three 3 year period the Renewal Term and collectively
# Processing row 3, category: Competitive Restriction Exception, answer: the Term unless either party provides the other with written notice of nonrenewal at least ninety 90 days before the expiration of the Initial Term
# Processing row 3, category: NonCompete, answer: This Agreement shall be governed by and construed in accordance with the internal laws of the State of Nevada without giving effect to any choice or conflict of law provision or rule
# Processing row 3, category: NonDisparagement, answer: Subject to Licensees onxadgoing compliance with Section 32 and all other terms and conditions of this Agreement
# Processing row 3, category: Termination For Convenience, answer: nontransferable except as provided in Section 117 and non sublicensable license
# Processing row 3, category: RofrRofoRofn, answer: to reproduce
# Processing row 3, category: Change Of Control, answer: display
# Processing row 3, category: AntiAssignment, answer: which is attached hereto and incorporated herein by this reference
# Processing row 3, category: Joint Ip Ownership, answer: For purposes of the preceding sentence
# Processing row 3, category: License Grant, answer: any merger
# Processing row 3, category: NonTransferable License, answer: obligations or performance under this Agreement for which Licensors prior written consent is required
# Processing row 3, category: Affiliate LicenseLicensor, answer: Any purported assignment
# Processing row 3, category: Affiliate LicenseLicensee, answer: Licensee shall not assign or otherwise transfer any of its rights
# Processing row 3, category: UnlimitedAllYouCanEatLicense, answer: under this Agreement
# Processing row 3, category: Irrevocable Or Perpetual License, answer: involuntarily
# Processing row 3, category: Source Code Escrow, answer: without Licensors prior written consent
# Processing row 3, category: PostTermination Services, answer: In addition to the License Fee payable in accordance with Section 51
# Processing row 3, category: Audit Rights, answer: 000 700 10
# Processing row 3, category: Uncapped Liability, answer: 000 800 15
# Processing row 3, category: Cap On Liability, answer: 000 850 20
# Processing row 3, category: Liquidated Damages, answer: 000 925 25
# Processing row 3, category: Warranty Duration, answer: Yes
# Processing row 3, category: Insurance, answer: No
# Processing row 3, category: Covenant Not To Sue, answer: No
# Processing row 3, category: Third Party Beneficiary, answer: No
# Processing row 4, category: Document Name, answer: December 21
# Processing row 4, category: Parties, answer: 122115
# Processing row 4, category: Agreement Date, answer: 2015
# Processing row 4, category: Effective Date, answer: The Term of this Agreement the Term shall commence on the Effective Date listed above and continue for twenty 20 years
# Processing row 4, category: Expiration Date, answer: 122135
# Processing row 4, category: Governing Law, answer: without giving effect to any conflicts of laws principles
# Processing row 4, category: RofrRofoRofn, answer: Should Licensee agree to be the vendor for an Additional Title
# Processing row 4, category: Change Of Control, answer: If
# Processing row 4, category: AntiAssignment, answer: Licensor develops or obtains the rights to license any live action or animated featurelength motion picture each an Additional Title
# Processing row 4, category: RevenueProfit Sharing, answer: the preferred vendor
# Processing row 4, category: Price Restrictions, answer: Yes
# Processing row 4, category: Minimum Commitment, answer: No
# Processing row 4, category: Volume Restriction, answer: Licensee may not sublicense any of its rights under Section 2a License Grant without Licensors prior written consent
# Processing row 4, category: Ip Ownership Assignment, answer: Licensee shall have the right to assign or sublicense any or all of its rights granted under this Agreement
# Processing row 4, category: Joint Ip Ownership, answer: to third parties exhibiting the Titles in the ordinary course of Licensees business with prior written notice to Licensor and subject to the applicable limitations if any in Section 2ai License Grant
# Processing row 4, category: License Grant, answer: duties or obligations under this Agreement to any third party in whole or in part
# Processing row 4, category: NonTransferable License, answer: except that i Licensee may assign its rights and obligations to this Agreement to any of its Affiliate or subsidiaries with the prior written consent of the Licensor
# Processing row 4, category: Affiliate LicenseLicensor, answer: Yes
# Processing row 4, category: Affiliate LicenseLicensee, answer: Licensor will only grant Licensee certain profit participation rights
# Processing row 4, category: UnlimitedAllYouCanEatLicense, answer: as detailed and set forth in Schedule A6 of Schedule A
# Processing row 4, category: Irrevocable Or Perpetual License, answer: dated as of December 21
# Processing row 4, category: Source Code Escrow, answer: by and among the Licensee and the Licensor the Share Consideration
# Processing row 4, category: Warranty Duration, answer: Limitations on Rights Granted the following distribution methods are permitted nontheatrical
# Processing row 4, category: Insurance, answer: ship and hotel rights all not earlier than the US theatrical release home video rental
# Processing row 4, category: Covenant Not To Sue, answer: and commercial video rights all not earlier than the US video release cable TV pay free
# Processing row 4, category: Third Party Beneficiary, answer: satellite pay TV internet TV pay free
# Processing row 5, category: Document Name, answer: Inc DeltaThree
# Processing row 5, category: Parties, answer: 1999
# Processing row 5, category: Agreement Date, answer: October 1
# Processing row 5, category: Effective Date, answer: 10199
# Processing row 5, category: Expiration Date, answer: unless terminated earlier in accordance with the provisions of this Agreement the Term provided
# Processing row 5, category: Renewal Term, answer: that PrimeCall may elect to terminate this Agreement
# Processing row 5, category: Notice Period To Terminate Renewal, answer: at any time from and after the time that collectively RSL Communications
# Processing row 5, category: Governing Law, answer: 10102
# Processing row 5, category: NonCompete, answer: and construed in accordance with
# Processing row 5, category: Exclusivity, answer: without giving effect to the conflict of laws principles thereof
# Processing row 5, category: Minimum Commitment, answer: The term of this Agreement shall be effective as of the date first stated above and shall continue for a term of three 3 years
# Processing row 5, category: Volume Restriction, answer: however
# Processing row 5, category: Ip Ownership Assignment, answer: upon thirty 30 days written notice
# Processing row 5, category: Joint Ip Ownership, answer: Ltd andor its Affiliates holds less than fifty percent 50 of the voting control of DeltaThrees outstanding shares
# Processing row 5, category: License Grant, answer: Except as provided in the preceding sentence
# Processing row 5, category: NonTransferable License, answer: This Agreement may not be assigned by DeltaThree without the prior written consent of PrimeCall
# Processing row 5, category: Audit Rights, answer: Throughout the Term of this Agreement
# Processing row 5, category: Uncapped Liability, answer: distribution
# Processing row 5, category: Cap On Liability, answer: Yes
# Processing row 5, category: Liquidated Damages, answer: No
# Processing row 5, category: Warranty Duration, answer: No
# Processing row 5, category: Insurance, answer: No
# Processing row 5, category: Covenant Not To Sue, answer: No
# Processing row 5, category: Third Party Beneficiary, answer: No
# Processing row 6, category: Document Name, answer: May 22
# Processing row 6, category: Parties, answer: 52200
# Processing row 6, category: Agreement Date, answer: 2000
# Processing row 6, category: Effective Date, answer: This Agreement will become effective as of the Effective Date and
# Processing row 6, category: Expiration Date, answer: shall remain effective for two 2 years from and after the Effective Date the Initial Term
# Processing row 6, category: Renewal Term, answer: This agreement shall automatically renew for additional successive terms of twelve 12 months each at the end of the Initial Term Renewal Terms
# Processing row 6, category: Notice Period To Terminate Renewal, answer: successive 1 year
# Processing row 6, category: Governing Law, answer: unless either party notifies the other in writing at least sixty 60 days prior to the end of the Initial Term
# Processing row 6, category: Most Favored Nation, answer: This Agreement shall be interpreted and enforced in accordance with the laws of the State of California as applied to agreements made
# Processing row 6, category: Competitive Restriction Exception, answer: notwithstanding the actual residence of the parties
# Processing row 6, category: NonCompete, answer: California
# Processing row 6, category: Exclusivity, answer: No
# Processing row 6, category: NoSolicit Of Customers, answer: Womencom shall be entitled to aa provide mini and micro web sites and Womencom promotions and sponsorships to Jenny Craig bb sell
# Processing row 6, category: NoSolicit Of Employees, answer: or distribute advertisements
# Processing row 6, category: NonDisparagement, answer: newsletter placements
# Processing row 6, category: Termination For Convenience, answer: commerce placements and market research
# Processing row 6, category: RofrRofoRofn, answer: Yes
# Processing row 6, category: Change Of Control, answer: a Womencom will not buy
# Processing row 6, category: AntiAssignment, answer: display
# Processing row 6, category: RevenueProfit Sharing, answer: but not limited to
# Processing row 6, category: Price Restrictions, answer: buttons
# Processing row 6, category: Minimum Commitment, answer: text links
# Processing row 6, category: Volume Restriction, answer: Yes
# Processing row 6, category: Ip Ownership Assignment, answer: eDiets will not buy
# Processing row 6, category: Joint Ip Ownership, answer: display or distribute advertising from including
# Processing row 6, category: License Grant, answer: banner ads
# Processing row 6, category: NonTransferable License, answer: badges
# Processing row 6, category: Affiliate LicenseLicensor, answer: hyperlinks or editorial mentions or otherwise promote any Womencom Compettive Company on any page of the eDiets Site that is within two clicks from the Gateway Page of the Diet Center
# Processing row 6, category: Affiliate LicenseLicensee, answer: Competitive Company means any company that eDiets reasonably presents as
# Processing row 6, category: UnlimitedAllYouCanEatLicense, answer: a direct competitor to eDiets by distributing online content principally relating to diets and diet counseling
# Processing row 6, category: Irrevocable Or Perpetual License, answer: but not limited to
# Processing row 6, category: Source Code Escrow, answer: Jenny Craig
# Processing row 6, category: PostTermination Services, answer: Nutrio
# Processing row 6, category: Audit Rights, answer: DietSmart and uMagic
# Processing row 6, category: Uncapped Liability, answer: Womencom Competitive Company means any company that Womencom reasonably presents as
# Processing row 6, category: Cap On Liability, answer: a direct competitor to Womencom by providing an online portal for women
# Processing row 6, category: Liquidated Damages, answer: but not limited to
# Processing row 6, category: Insurance, answer: Womencom shall be entitled to aa provide mini and micro web sites and Womencom promotions and sponsorships to Jenny Craig bb sell
# Processing row 6, category: Covenant Not To Sue, answer: or distribute advertisements
# Processing row 6, category: Third Party Beneficiary, answer: newsletter placements
# Processing row 7, category: Document Name, answer: 10th day of January 2000
# Processing row 7, category: Agreement Date, answer: This agreement shall commence as of date first above written
# Processing row 7, category: Effective Date, answer: 2004 the Term
# Processing row 7, category: Notice Period To Terminate Renewal, answer: This Agreement has been entered into in the State of Tennessee
# Processing row 7, category: Governing Law, answer: interpretation and legal effect of this Agreement will be governed by the laws of the State of Tennessee applicable to contracts entered into and performed entirely within the State of Tennessee
# Processing row 7, category: Most Favored Nation, answer: If for any reason
# Processing row 7, category: Competitive Restriction Exception, answer: the foregoing shall be adjusted to comply with any such licenses
# Processing row 7, category: NoSolicit Of Customers, answer: Integrity will hold exclusive worldwide rights to promote and sell the product tothrough the following distribution channels Christian retail CBA or Christian Booksellers Association markets
# Processing row 7, category: NoSolicit Of Employees, answer: church sales
# Processing row 7, category: NonDisparagement, answer: TL will hold exclusive worldwide rights to promote and sell the product through the following distribution channels Outgoing telemarketing
# Processing row 7, category: Termination For Convenience, answer: and General Market catalogs
# Processing row 7, category: RofrRofoRofn, answer: Yes
# Processing row 7, category: Change Of Control, answer: No
# Processing row 7, category: AntiAssignment, answer: No
# Processing row 7, category: RevenueProfit Sharing, answer: No
# Processing row 7, category: Price Restrictions, answer: No
# Processing row 7, category: Minimum Commitment, answer: No
# Processing row 7, category: Volume Restriction, answer: No
# Processing row 7, category: Ip Ownership Assignment, answer: at its election
# Processing row 7, category: Joint Ip Ownership, answer: in whole or in part
# Processing row 7, category: License Grant, answer: firm or corporation owning or acquiring all or a substantial portion of its assets
# Processing row 7, category: NonTransferable License, answer: firm or corporation that is related to it as an affiliate
# Processing row 7, category: Affiliate LicenseLicensor, answer: or to any person
# Processing row 7, category: Affiliate LicenseLicensee, answer: In the event of such anomittedassignment by either party of its rights to an unrelated third party
# Processing row 7, category: UnlimitedAllYouCanEatLicense, answer: then in such event the other party may upon sixmonths 6months written notice terminate this Agreement
# Processing row 7, category: Irrevocable Or Perpetual License, answer: On sales of recorded products pursuant to this Agreement less any returns Integrity will pay to TL royalties in the amount of 1 1 for each and every unit of the product sold by Integrity in the United States pursuant to this Agreement
# Processing row 7, category: Source Code Escrow, answer: whichever is less
# Processing row 7, category: PostTermination Services, answer: On sales of printed products song books pursuant to this Agreement less any returns Integrity will pay to TL royalties in the amount of 1 1 for each and every unit of the product sold by Integrity in the United States pursuant to this Agreement
# Processing row 7, category: Audit Rights, answer: whichever is less
# Processing row 7, category: Uncapped Liability, answer: On sales of products pursuant to this Agreement less any returns TL will pay to Integrity royalties in the amount of 1 1 for each and every unit of the product sold by it pursuant to this Agreement
# Processing row 7, category: Liquidated Damages, answer: In consideration of the above pricing
# Processing row 7, category: Warranty Duration, answer: 000 units of each recorded Product during the first thirtytwo 32 months of release
# Processing row 7, category: Insurance, answer: 000 units
# Processing row 7, category: Covenant Not To Sue, answer: TL may purchase from Integrity limited quantities of the Product for its promotional use
# Processing row 7, category: Third Party Beneficiary, answer: provided the quantity of such purchases does not exceed seven percent 7 of the total royalty bearing units of such Product title purchased by TL
# Processing row 8, category: Document Name, answer: Endorser and Fitness AS Parties MusclePharm Corporation MusclePharm or Company
# Processing row 8, category: Parties, answer: 2013
# Processing row 8, category: Agreement Date, answer: July 26
# Processing row 8, category: Effective Date, answer: 72613
# Processing row 8, category: Expiration Date, answer: 2013 and shall expire on July 22
# Processing row 8, category: Renewal Term, answer: unless otherwise terminated earlier pursuant to Section 9 of this Agreement
# Processing row 8, category: Notice Period To Terminate Renewal, answer: 72216
# Processing row 8, category: Governing Law, answer: then the Second Additional Term shall commence on July 23
# Processing row 8, category: Most Favored Nation, answer: 2022
# Processing row 8, category: Competitive Restriction Exception, answer: then this Agreement shall automatically be renewed for an additional term of three 3 years the First Additional Term on the same terms and conditions for the Initial Term except that i no additional Stock Compensation as defined below shall be issued in connection with the renewal Term
# Processing row 8, category: NonCompete, answer: iii Endorser shall only be obligated to make two 2 Appearances in each Contract Year during the First Additional Term pursuant to Section 4aii below and iv the marketing budget to promote the Licensed Products shall be 50 million during each Contract Year of the First Additional Term subject to Section 12b of this Agreement
# Processing row 8, category: Exclusivity, answer: then the First Additional Term shall commence on July 23
# Processing row 8, category: NoSolicit Of Customers, answer: and the Agreement shall expire and terminate automatically without further notice on July 22
# Processing row 8, category: NoSolicit Of Employees, answer: In the event that MusclePharm shall achieve Net Sales of 50 million the Second Renewal Threshold in the aggregate during the sixth Contract Year
# Processing row 8, category: NonDisparagement, answer: ii the Cash Compensation for the renewal Term shall be as set forth in Section 7 and Exhibit C Section 3 attached hereto
# Processing row 8, category: Termination For Convenience, answer: 7222019 7222022
# Processing row 8, category: Change Of Control, answer: and its interpretation
# Processing row 8, category: AntiAssignment, answer: California
# Processing row 8, category: RevenueProfit Sharing, answer: No
# Processing row 8, category: Price Restrictions, answer: the following will not be a breach of this Agreement i Endorsers performance of services or appearing in the news or informational portion of any radio
# Processing row 8, category: Minimum Commitment, answer: commercial tieins andor product placements utilizing Endorser
# Processing row 8, category: Volume Restriction, answer: appearance or use of his name
# Processing row 8, category: Ip Ownership Assignment, answer: sports events
# Processing row 8, category: Joint Ip Ownership, answer: regardless of usage of products or services andor sponsorship thereof
# Processing row 8, category: License Grant, answer: this Agreement shall not prevent or shall in any manner restrict Endorser from advertising
# Processing row 8, category: NonTransferable License, answer: vitamins
# Processing row 8, category: Affiliate LicenseLicensor, answer: amino acids
# Processing row 8, category: Affiliate LicenseLicensee, answer: legal performance enhancing substances provided the primary purpose of such product or company is not to sell or market a dietary supplement
# Processing row 8, category: UnlimitedAllYouCanEatLicense, answer: Products Any failure of Endorser to disclose such conflicting interests
# Processing row 8, category: Irrevocable Or Perpetual License, answer: shall be deemed a material breach of the Agreement
# Processing row 8, category: Source Code Escrow, answer: Endorsers duty not to compete with the business of MusclePharm shall continue for a period of one year following the expiration or termination of this Agreement Endorsers noncompetition obligation shall not be required in the event of a material breach of this Agreement by MusclePharm
# Processing row 8, category: PostTermination Services, answer: Yes
# Processing row 8, category: Audit Rights, answer: or any extensions of this Agreement
# Processing row 8, category: Uncapped Liability, answer: image andor likeness for advertising
# Processing row 8, category: Cap On Liability, answer: Yes
# Processing row 8, category: Liquidated Damages, answer: No
# Processing row 8, category: Warranty Duration, answer: No
# Processing row 8, category: Insurance, answer: No
# Processing row 8, category: Covenant Not To Sue, answer: No
# Processing row 8, category: Third Party Beneficiary, answer: if any
# Processing row 9, category: Document Name, answer: Online BVI and the Company Party and collectively as Parties Skype
# Processing row 9, category: Parties, answer: the Company
# Processing row 9, category: Agreement Date, answer: 22nd day of August 2005
# Processing row 9, category: Effective Date, answer: 22nd day of August 2005
# Processing row 9, category: Expiration Date, answer: The term of this Agreement shall continue for a period of five years following the initial date of execution of the Memorandum
# Processing row 9, category: Renewal Term, answer: 82210
# Processing row 9, category: Notice Period To Terminate Renewal, answer: for an additional period of three 3 years
# Processing row 9, category: Governing Law, answer: with the Initial Term
# Processing row 9, category: Most Favored Nation, answer: 3 years
# Processing row 9, category: Competitive Restriction Exception, answer: for an additional period of three 3 years
# Processing row 9, category: NonCompete, answer: with the Initial Term
# Processing row 9, category: Exclusivity, answer: 60 days
# Processing row 9, category: NoSolicit Of Customers, answer: without regard to conflict of laws principles
# Processing row 9, category: NoSolicit Of Employees, answer: United Kingdom Wales
# Processing row 9, category: NonDisparagement, answer: The Company will
# Processing row 9, category: Termination For Convenience, answer: use its commercially reasonable efforts to make available and promote the Online Groups existing payment processing and customer billing and payment gateway methods for the purchase of Skype premium features by CompanySkype Branded Customers
# Processing row 9, category: RofrRofoRofn, answer: without limitation
# Processing row 9, category: Change Of Control, answer: vouchers and mobile payment methods
# Processing row 9, category: AntiAssignment, answer: that all payment processing and customer billing and payment gateway charges for such payment methods are on terms that are as or more favourable than the most favourable pricing and terms for such services otherwise provided at the applicable time by any member of the Online Group
# Processing row 9, category: RevenueProfit Sharing, answer: Yes
# Processing row 9, category: Price Restrictions, answer: the foregoing restrictions shall not applynn821 a i for the avoidance of doubt
# Processing row 9, category: Minimum Commitment, answer: or ii the operations of Skype customers and Affiliates under any agreement existing as of the date hereof eg
# Processing row 9, category: Volume Restriction, answer: or b to any agreement now existing or hereafter entered into with an entity that operates in multiple international markets
# Processing row 9, category: Ip Ownership Assignment, answer: so long as such agreement applies to multiple territories
# Processing row 9, category: Joint Ip Ownership, answer: and does not
# Processing row 9, category: License Grant, answer: allow or provide for distribution in the PRC of the Skype Software in simplified Chinese by a Primarily PRC Based Service Provider other than any service provider formed for the sole purpose of performing such agreement and not operating in the PRC prior to the date of such agreement
# Processing row 9, category: NonTransferable License, answer: except in the case where the Affiliate Program
# Processing row 9, category: Affiliate LicenseLicensor, answer: allows or provides for distribution in the PRC of the Skype Software in simplified Chinese by a Primarily PRC Based Service Provider other than any service provider formed for the sole purpose of performing such agreement and not operating in the PRC prior to the date of such agreement ornn822 with respect to the provisions of Section 812
# Processing row 9, category: Affiliate LicenseLicensee, answer: Yes
# Processing row 9, category: UnlimitedAllYouCanEatLicense, answer: the NonCompetition Period shall terminate prior to the End Date
# Processing row 9, category: Irrevocable Or Perpetual License, answer: no party shall be obligated to comply with the restrictions set out in Section 81 after the termination of the NonCompetition Period
# Processing row 9, category: Source Code Escrow, answer: from the Effective Date and through the three 3 month period Enterprise NonCompetition Period immediately following the date Enterprise Launch Date that Skype launches an enterprise version of the Skype Software primarily targeted for nonConsumer customers Enterprise Skype Software
# Processing row 9, category: PostTermination Services, answer: nor any of their respective Subsidiaries
# Processing row 9, category: Audit Rights, answer: negotiate or enter into whether verbal or in writing with any third Person or other third party Other Party any understanding
# Processing row 9, category: Uncapped Liability, answer: or memorandum of understanding
# Processing row 9, category: Cap On Liability, answer: agreement or any other documents whether or not legally binding andor ii voluntarily accept or solicit any offer made by any Other Party in respect of or in relation to
# Processing row 9, category: Liquidated Damages, answer: an enterprise cobranded Internetbased application in simplified Chinese that is focused on
# Processing row 9, category: Warranty Duration, answer: nonConsumers within the PRC
# Processing row 9, category: Insurance, answer: and b in the case of Online BVI
# Processing row 9, category: Covenant Not To Sue, answer: any voice over internet protocol andor instant messaging products or services that compete or are likely to compete with the Enterprise Skype Software
# Processing row 9, category: Third Party Beneficiary, answer: for a period of five years NonCompetition Period from the Effective Date End Date
# Processing row 10, category: Document Name, answer: September 30
# Processing row 10, category: Parties, answer: 93019
# Processing row 10, category: Agreement Date, answer: 2019
# Processing row 10, category: Effective Date, answer: The term of this Agreement shall begin as of the Effective Date and continue until Acceptance of all Deliverables for Milestones 1 and 2 pursuant to Section 34 and completion of Milestone 3
# Processing row 10, category: Expiration Date, answer: as provided for under the Other Agreements
# Processing row 10, category: Most Favored Nation, answer: New York
# Processing row 10, category: Competitive Restriction Exception, answer: No
# Processing row 10, category: NonCompete, answer: the foregoing does not prevent Conformis from granting any license
# Processing row 10, category: Exclusivity, answer: covenant not to sue or other immunity to any third party under any Patents
# Processing row 10, category: NoSolicit Of Customers, answer: use or sale of PatientSpecific Instrumentation for OffTheShelf Knee Implants outside the Buyer Field
# Processing row 10, category: NoSolicit Of Employees, answer: Conformis shall be prohibited from developing or assisting another in developing
# Processing row 10, category: NonDisparagement, answer: PatientSpecific Instrumentation for OffTheShelf Knee Implants for any Third Party in the field of orthopedics until January 1
# Processing row 10, category: Termination For Convenience, answer: to the extent set forth in Section 2334 or Section 235 of the Distribution Agreement
# Processing row 10, category: RofrRofoRofn, answer: any such entity an Acquirer
# Processing row 10, category: Change Of Control, answer: an Acquirer or any of their Affiliates
# Processing row 10, category: RevenueProfit Sharing, answer: Except as specifically provided in the Distribution Agreement
# Processing row 10, category: Price Restrictions, answer: or causing another to develop
# Processing row 10, category: Minimum Commitment, answer: 2032 or earlier
# Processing row 10, category: Volume Restriction, answer: with the exception that Conformis including any entity involved in a Change of Control of Conformis
# Processing row 10, category: Ip Ownership Assignment, answer: may develop PatientSpecific Instrumentation for any OffThe Shelf Implants of Conformis
# Processing row 10, category: Joint Ip Ownership, answer: Yes
# Processing row 10, category: License Grant, answer: No
# Processing row 10, category: NonTransferable License, answer: No
# Processing row 10, category: Affiliate LicenseLicensor, answer: No
# Processing row 10, category: Affiliate LicenseLicensee, answer: No
# Processing row 10, category: UnlimitedAllYouCanEatLicense, answer: in the event that the applicable Party decides not to file at all or not to file a continuing or other application to maintain the viability of the US part of a family of patents to which an application belongs
# Processing row 10, category: Irrevocable Or Perpetual License, answer: such Party shall notify the other Party thereof
# Processing row 10, category: Source Code Escrow, answer: Yes
# Processing row 10, category: PostTermination Services, answer: a Party shall not have the right to assign any of its rights or obligations under this Agreement whether through a merger
# Processing row 10, category: Audit Rights, answer: or otherwise without the prior written consent of the other Party except that
# Processing row 10, category: Uncapped Liability, answer: without any need for the other Partys consent
# Processing row 10, category: Cap On Liability, answer: however
# Processing row 10, category: Liquidated Damages, answer: such former Affiliate shall assign this Agreement back to the assigning Party
# Processing row 10, category: Warranty Duration, answer: whether by Change of Control
# Processing row 10, category: Insurance, answer: sale of assets or otherwise provided
# Processing row 10, category: Covenant Not To Sue, answer: that
# Processing row 10, category: Third Party Beneficiary, answer: i any assignment of this Agreement shall be void and have no effect unless and until the assignee assumes theomittedobligations of the assigning Party in a written instrument
# Processing row 11, category: Document Name, answer: June 12
# Processing row 11, category: Parties, answer: 61219
# Processing row 11, category: Agreement Date, answer: provided that ETON has exercised best efforts to execute such agreement and the failure to execute is solely caused by the refusal or inability of the proposed manufacturing organization to sign a reasonable agreement and ii acceptance for review of the Dossier or marketing application for by the FDA no later than September 2
# Processing row 11, category: Effective Date, answer: the Effective Date and shall end upon the termination or expiration of the Agreement as set forth in Section 11 the Term
# Processing row 11, category: Expiration Date, answer: The term of this Agreement shall automatically become effective upon the occurrence of i ETON executing a commercial supply agreement with a contract manufacturing organization within fortyfive 45 days of the Execution Date
# Processing row 11, category: Renewal Term, answer: 2019 such date
# Processing row 11, category: Notice Period To Terminate Renewal, answer: Perpetual
# Processing row 11, category: Competitive Restriction Exception, answer: interpreted and construed in accordance with the substantive laws of the Delaware
# Processing row 11, category: NonCompete, answer: without regard to its conflict of laws principles
# Processing row 11, category: NoSolicit Of Employees, answer: During the Term of this Agreement
# Processing row 11, category: NonDisparagement, answer: Aucta shall not research
# Processing row 11, category: Termination For Convenience, answer: manufacture
# Processing row 11, category: RofrRofoRofn, answer: sell
# Processing row 11, category: Change Of Control, answer: or distribute more than two products containing the active ingredient Lamotrigine nor will Aucta directly or indirectly assist any other Person or entity in carrying or any such activities
# Processing row 11, category: AntiAssignment, answer: Aucta
# Processing row 11, category: RevenueProfit Sharing, answer: hereby grants to ETON in accordance with the terms and conditions of this Agreement
# Processing row 11, category: Price Restrictions, answer: including the right to sublicense
# Processing row 11, category: Minimum Commitment, answer: Dossiers
# Processing row 11, category: Volume Restriction, answer: manufacture
# Processing row 11, category: Ip Ownership Assignment, answer: use
# Processing row 11, category: Joint Ip Ownership, answer: distribute
# Processing row 11, category: License Grant, answer: advertise
# Processing row 11, category: NonTransferable License, answer: Market the Products in and for the Territory
# Processing row 11, category: Irrevocable Or Perpetual License, answer: ETON has the right to terminate this Agreement after approval of the Dossier or marketing application for the Product or added new product
# Processing row 11, category: Source Code Escrow, answer: upon providing one hundred eighty 180 days written notice to Aucta
# Processing row 11, category: Audit Rights, answer: Notwithstanding the foregoing
# Processing row 11, category: Uncapped Liability, answer: without consent of the other Party
# Processing row 11, category: Cap On Liability, answer: consolidation or change in control provided that the assignee assumes in writing and becomes directly obligated to the other Party to perform all of the obligations of assignor under this Agreement
# Processing row 11, category: Liquidated Damages, answer: The Parties shall not assign
# Processing row 11, category: Warranty Duration, answer: without the prior written consent of the other Party
# Processing row 11, category: Insurance, answer: ETON shall pay to Aucta a royalty payment of of Net Sales of the Products
# Processing row 11, category: Covenant Not To Sue, answer: unless otherwise agreed to under this Agreement
# Processing row 12, category: Document Name, answer: November 5
# Processing row 12, category: Parties, answer: 11519
# Processing row 12, category: Agreement Date, answer: 2019
# Processing row 12, category: Effective Date, answer: Unless sooner terminated in accordance with this Article
# Processing row 12, category: Expiration Date, answer: 103121
# Processing row 12, category: Governing Law, answer: New York
# Processing row 12, category: Most Favored Nation, answer: No
# Processing row 12, category: Competitive Restriction Exception, answer: ExxonMobil hereby grants approval for FCE solely to conduct Authorized Work using Generation 1 Technology with Authorized Third Parties for Carbon Capture Applications and any Work using Generation 2 Technology solely for Power Applications and Hydrogen Applications
# Processing row 12, category: NonCompete, answer: During the Term of this Agreement
# Processing row 12, category: Exclusivity, answer: independently or with third parties outside this Agreement
# Processing row 12, category: NoSolicit Of Customers, answer: Yes
# Processing row 12, category: NoSolicit Of Employees, answer: No
# Processing row 12, category: NonDisparagement, answer: No
# Processing row 12, category: Termination For Convenience, answer: No
# Processing row 12, category: RofrRofoRofn, answer: No
# Processing row 12, category: Change Of Control, answer: either Party may terminate this Agreement or allpart of a Project for any reason and at any time upon giving the other Party sixty 60 days prior written notice
# Processing row 12, category: AntiAssignment, answer: Notwithstanding the foregoing
# Processing row 12, category: RevenueProfit Sharing, answer: defend
# Processing row 12, category: Price Restrictions, answer: maintain or decides to abandon any Program Patent
# Processing row 12, category: Minimum Commitment, answer: and FCE will then have the right
# Processing row 12, category: Volume Restriction, answer: to prosecute or maintain the Program Patent and sole responsibility for the continuing costs
# ...
# Processing row 540, category: NonDisparagement, answer: Licensor hereby grants to Licensee an exclusive in the Territory to 1 make Sublicense Copies and copies of the Documentation to meet the demand of Redistributors and Customers and 2 market and sublicense Sublicense Copies and copies of the Documentation
# Processing row 540, category: Termination For Convenience, answer: Yes
# Processing row 540, category: RofrRofoRofn, answer: No
# Processing row 540, category: Change Of Control, answer: No
# Processing row 540, category: AntiAssignment, answer: No
# Processing row 540, category: RevenueProfit Sharing, answer: No
# Processing row 540, category: Price Restrictions, answer: No
# Processing row 540, category: Minimum Commitment, answer: the acquisition of the majority of Licensees issued and outstanding capital stock or the acquisition of substantially all of the assets of Licensee
# Processing row 540, category: Volume Restriction, answer: Neither this Agreement nor any of the rights
# Processing row 540, category: Ip Ownership Assignment, answer: however
# Processing row 540, category: Joint Ip Ownership, answer: controlled by or under common control with Licensor
# Processing row 540, category: License Grant, answer: Licensee shall pay to Licensor for each Licensed Product licensed to a Redistributor or a Customer a licensee fee equal to 50 of all revenues received without deduction for value added tax
# Processing row 540, category: NonTransferable License, answer: but excluding any revenues for maintenance and support or upgrade services
# Processing row 540, category: Affiliate LicenseLicensor, answer: Licensee shall pay to Licensor for maintenance and support and upgrade services provided under the applicable Sublicense or other written maintenance and support agreement with or approved by Licensee for each of the Licensed Products a fee equal to 50 of all revenues received without deduction for value added tax
# Processing row 540, category: Affiliate LicenseLicensee, answer: Yes
# Processing row 540, category: UnlimitedAllYouCanEatLicense, answer: No
# Processing row 540, category: Irrevocable Or Perpetual License, answer: the term Quota Amount means 50
# Processing row 540, category: Source Code Escrow, answer: 000 If Licensor fails to deliver notice of termination pursuant to this subsection 142b1 within six 6 months after the end of the term to which such termination relates
# Processing row 540, category: PostTermination Services, answer: Yes
# Processing row 540, category: Audit Rights, answer: No
# Processing row 540, category: Uncapped Liability, answer: No
# Processing row 540, category: Cap On Liability, answer: No
# Processing row 540, category: Liquidated Damages, answer: service marks
# Processing row 540, category: Warranty Duration, answer: copyrights
# Processing row 540, category: Insurance, answer: the Marks relating to the Licensed Products or the Documentation during the term of this Agreement in the marketing by Licensee of the Licensed Products
# Processing row 540, category: Covenant Not To Sue, answer: Licensor hereby grants to Licensee a non exclusive
# Processing row 540, category: Third Party Beneficiary, answer: demonstration to Redistributors and Customers
# Processing row 541, category: Document Name, answer: 1999
# Processing row 541, category: Parties, answer: The term of this Agreement shall begin on January 1
# Processing row 541, category: Agreement Date, answer: and may be renewed under Section 8 hereof the initial period plus any renewal period
# Processing row 541, category: Effective Date, answer: 1100
# Processing row 541, category: Expiration Date, answer: 2000 and continue for an initial period of five 5 years unless earlier terminated in accordance with Section 7 hereof
# Processing row 541, category: Renewal Term, answer: the Term
# Processing row 541, category: Notice Period To Terminate Renewal, answer: The Company may renew this Agreement on the same terms and conditions for one 1 additional five year period that shall begin on January 1
# Processing row 541, category: Governing Law, answer: 2009
# Processing row 541, category: Most Favored Nation, answer: 2004
# Processing row 541, category: NonCompete, answer: The validity
# Processing row 541, category: Exclusivity, answer: construction and performance of this Agreement shall be governed in accordance with the laws of the State of New Jersey without giving effect to the principles of conflicts of laws of such state
# Processing row 541, category: NonDisparagement, answer: To avoid any possibility of confusion of the public
# Processing row 541, category: Termination For Convenience, answer: the Professional agrees not to endorse
# Processing row 541, category: RofrRofoRofn, answer: likeness or image in connection with another companys golf clubs or golfrelated clothing or equipment during the Term and for a period of two 2 years thereafter
# Processing row 541, category: Change Of Control, answer: and will prohibit any caddy of hers from bearing any such identification
# Processing row 541, category: AntiAssignment, answer: and not to acquire any such interest during the Term
# Processing row 541, category: RevenueProfit Sharing, answer: The Professional hereby grants to the Company an exclusive license to use her name
# Processing row 541, category: Price Restrictions, answer: image and personal identification
# Processing row 541, category: Minimum Commitment, answer: in connection with the production
# Processing row 541, category: Volume Restriction, answer: marketing and sale of a Kathy Whitworth signature line of womens golf clubs the Products
# Processing row 541, category: Ip Ownership Assignment, answer: The Professional hereby grants to the Company the exclusive and worldwide right to use her name
# Processing row 541, category: Joint Ip Ownership, answer: image and personal identification
# Processing row 541, category: License Grant, answer: during the Term and for a period of six 6 months after the Term as provided in Section 28
# Processing row 541, category: NonTransferable License, answer: the Advertisements for any golf equipment
# Processing row 541, category: Affiliate LicenseLicensor, answer: videos
# Processing row 541, category: Affiliate LicenseLicensee, answer: The Professional hereby grants to the Company an exclusive license to use her name
# Processing row 541, category: UnlimitedAllYouCanEatLicense, answer: image and personal identification in the Companys catalog of products
# Processing row 541, category: Irrevocable Or Perpetual License, answer: whether professional or social
# Processing row 541, category: Source Code Escrow, answer: The Professional hereby grants an exclusive
# Processing row 541, category: PostTermination Services, answer: likeness
# Processing row 541, category: Audit Rights, answer: during the Term and for a period of six 6 months after the Term as provided in Section 28
# Processing row 541, category: Uncapped Liability, answer: manufacture
# Processing row 541, category: Cap On Liability, answer: sale and promotion of the Products
# Processing row 541, category: Insurance, answer: acts or omissions reasonably determined by the Company to be prejudicial or injurious to the business or goodwill of the Company
# Processing row 541, category: Covenant Not To Sue, answer: employees
# Processing row 541, category: Third Party Beneficiary, answer: the golf industry or professional golf and
# Processing row 542, category: Notice Period To Terminate Renewal, answer: No
# Processing row 542, category: Governing Law, answer: No
# Processing row 542, category: Most Favored Nation, answer: No
# Processing row 542, category: Competitive Restriction Exception, answer: No
# Processing row 542, category: NonCompete, answer: No
# Processing row 542, category: Exclusivity, answer: No
# Processing row 542, category: NoSolicit Of Customers, answer: No
# Processing row 542, category: NoSolicit Of Employees, answer: No
# Processing row 542, category: NonDisparagement, answer: No
# Processing row 542, category: Termination For Convenience, answer: No
# Processing row 542, category: RofrRofoRofn, answer: No
# Processing row 542, category: Change Of Control, answer: No
# Processing row 542, category: AntiAssignment, answer: No
# Processing row 542, category: RevenueProfit Sharing, answer: No
# Processing row 542, category: Price Restrictions, answer: No
# Processing row 542, category: Minimum Commitment, answer: acknowledge and deliver any documentation
# Processing row 542, category: Volume Restriction, answer: specifications or disclosures necessary to assign
# Processing row 542, category: Ip Ownership Assignment, answer: protect
# Processing row 542, category: Joint Ip Ownership, answer: Recipient hereby assigns and agrees to assign all Recipients rights in any Intellectual Property to the Company Recipient hereby grants to the Company power of attorney for the purpose of assigning all Recipients rights in Intellectual Property to the Company for the purposes of filings
# Processing row 542, category: License Grant, answer: protect
# Processing row 542, category: NonTransferable License, answer: Yes
# Processing row 542, category: Affiliate LicenseLicensor, answer: No
# Processing row 542, category: Affiliate LicenseLicensee, answer: No
# Processing row 542, category: UnlimitedAllYouCanEatLicense, answer: No
# Processing row 542, category: Irrevocable Or Perpetual License, answer: No
# Processing row 542, category: Source Code Escrow, answer: No
# Processing row 542, category: PostTermination Services, answer: No
# Processing row 542, category: Audit Rights, answer: No
# Processing row 542, category: Uncapped Liability, answer: No
# Processing row 542, category: Cap On Liability, answer: No
# Processing row 542, category: Liquidated Damages, answer: No
# Processing row 542, category: Warranty Duration, answer: No
# Processing row 542, category: Insurance, answer: No
# Processing row 542, category: Covenant Not To Sue, answer: No
# Processing row 542, category: Third Party Beneficiary, answer: No
# Processing row 543, category: Document Name, answer: 32620
# Processing row 543, category: Parties, answer: 2020
# Processing row 543, category: Governing Law, answer: Provided however
# Processing row 543, category: Most Favored Nation, answer: in writing
# Processing row 543, category: Competitive Restriction Exception, answer: Yes
# Processing row 543, category: NonCompete, answer: No
# Processing row 543, category: Exclusivity, answer: No
# Processing row 543, category: NoSolicit Of Customers, answer: and for a period of one 1 year following the expiration or earlier termination thereof
# Processing row 543, category: NoSolicit Of Employees, answer: directly or indirectly
# Processing row 543, category: NonDisparagement, answer: without the express written consent of Kubient and compensation to Kubient under the applicable exhibit andor schedule
# Processing row 543, category: Termination For Convenience, answer: During the Term and any renewal terms of the Agreement
# Processing row 543, category: RofrRofoRofn, answer: Customer shall not
# Processing row 543, category: Change Of Control, answer: directly or indirectly i solicit or encourage any person to leave the employment or other service of Kubient or ii hire
# Processing row 543, category: AntiAssignment, answer: any person who has left the employment of Kubient within the one 1 year period following the termination or end of that persons employment
# Processing row 543, category: RevenueProfit Sharing, answer: and for a period of one 1 year following the expiration or earlier termination thereof
# Processing row 543, category: Price Restrictions, answer: whether for its own account or for the account of any other person or entity
# Processing row 543, category: Minimum Commitment, answer: or endeavor to entice away from Kubient
# Processing row 543, category: Volume Restriction, answer: Yes
# Processing row 543, category: Ip Ownership Assignment, answer: No
# Processing row 543, category: Joint Ip Ownership, answer: No
# Processing row 543, category: License Grant, answer: No
# Processing row 543, category: NonTransferable License, answer: No
# Processing row 543, category: Affiliate LicenseLicensor, answer: No
# Processing row 543, category: Affiliate LicenseLicensee, answer: 2020 and thereafter
# Processing row 543, category: UnlimitedAllYouCanEatLicense, answer: including but not limited to its content
# Processing row 543, category: Irrevocable Or Perpetual License, answer: traffic
# Processing row 543, category: Source Code Escrow, answer: websites
# Processing row 543, category: PostTermination Services, answer: videos and podcasts
# Processing row 543, category: Audit Rights, answer: as per the attached Schedule 1
# Processing row 543, category: Uncapped Liability, answer: 00000 90 10 50 50 Video 30
# Processing row 543, category: Cap On Liability, answer: 00000 100 0 50 50 DataNewsletter 0 0 50 50 Podcasts 0 0 50 50 Other 0 0 50 50
# Processing row 544, category: Document Name, answer: 2020
# Processing row 544, category: Parties, answer: the 5th day of February
# Processing row 544, category: Effective Date, answer: 2521
# Processing row 544, category: Expiration Date, answer: such additional periods the Term
# Processing row 544, category: Notice Period To Terminate Renewal, answer: This Agreement is governed in all respects by the laws of the State of Delaware without giving effect to its conflict of laws principles
# Processing row 544, category: NonDisparagement, answer: Either Party may terminate this Agreement for any reason following the Initial Term upon ninety 90 days written notice to the other Party
# Processing row 544, category: Change Of Control, answer: Customer agrees that it will not transfer or unless expressly and specifically approved by Kubient in advance and in writing allow thirdparty access to the Service
# Processing row 544, category: AntiAssignment, answer: translate
# Processing row 544, category: RevenueProfit Sharing, answer: tamper with
# Processing row 544, category: Price Restrictions, answer: or otherwise create derivative works of any software included in any Service reverse engineer
# Processing row 544, category: Minimum Commitment, answer: or decompile any software or Service or apply any other process or procedure to derive source code of any software included in any Service or resell
# Processing row 544, category: Volume Restriction, answer: assign
# Processing row 544, category: Ip Ownership Assignment, answer: Neither Party may assign voluntarily
# Processing row 544, category: Joint Ip Ownership, answer: or otherwise this Agreement or any rights or obligations under this Agreement without the other Partys prior written consent
# Processing row 544, category: License Grant, answer: provided however
# Processing row 544, category: NonTransferable License, answer: stock sale
# Processing row 544, category: Affiliate LicenseLicensor, answer: Yes
# Processing row 544, category: Affiliate LicenseLicensee, answer: or Customers use of the Services or the Auction Platform
# Processing row 544, category: UnlimitedAllYouCanEatLicense, answer: Yes
# Processing row 544, category: Irrevocable Or Perpetual License, answer: No
# Processing row 544, category: Source Code Escrow, answer: No
# Processing row 544, category: PostTermination Services, answer: No
# Processing row 544, category: Audit Rights, answer: No
# Processing row 544, category: Uncapped Liability, answer: No
# Processing row 544, category: Cap On Liability, answer: Kubient hereby grants to Customer a limited
# Processing row 544, category: Liquidated Damages, answer: nonexclusive
# Processing row 544, category: Warranty Duration, answer: nonassignable
# Processing row 544, category: Insurance, answer: revocable license to access
# Processing row 544, category: Covenant Not To Sue, answer: for the purpose of serving Inventory at Target Demand u202fu202fu202fu202fu202fu202fu202fu202fu202fu202f
# Processing row 544, category: Third Party Beneficiary, answer: In the event Customer shall utilize Kubients ad serving technology as part of the Services

# %%
CUAD_TRAIN_PATH = CUAD_PATH/'train'
CUAD_VALIDATION_PATH = CUAD_PATH/'validation'

# %%
save_jsonl(train_data, CUAD_TRAIN_PATH/'cuad_train.jsonl')
save_jsonl(val_data, CUAD_VALIDATION_PATH/'cuad_validation.jsonl')
print(f"Saved {len(train_data)} training samples and {len(val_data)} validation samples.")
# Out:
# Saved 13767 training samples and 1530 validation samples.

# %%
import torch
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
)
from peft import LoraConfig
from trl import SFTTrainer

# 1. Configuration
model_name = "meta-llama/Meta-Llama-3-8B" # or "mistralai/Mistral-7B-v0.1"
new_model_name = "llama-3-cuad-finetune"

# 2. QLoRA Config (4-bit loading to fit on consumer GPU)
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
)

# 3. Load Base Model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map="auto"
)
model.config.use_cache = False # Silence warnings during training

# 4. Load Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right" # Fix for fp16

# 5. Load Dataset
dataset = load_dataset("json", data_files={"train": "data/train.jsonl", "validation": "data/validation.jsonl"})

# 6. LoRA Configuration
peft_config = LoraConfig(
    r=16,       # Rank (Higher = more parameters to train, 16-64 is standard)
    lora_alpha=16,
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=["q_proj", "v_proj"] # Specific to Llama/Mistral architecture
)

# 7. Training Arguments
training_args = TrainingArguments(
    output_dir="./results",
    num_train_epochs=1,           # 1 epoch is often enough for SFT on small datasets
    per_device_train_batch_size=4,
    gradient_accumulation_steps=1,
    learning_rate=2e-4,
    weight_decay=0.001,
    fp16=True,
    logging_steps=25,
    save_steps=100,
    optim="paged_adamw_32bit",    # Syllabus optimization
)

# 8. Initialize Trainer
trainer = SFTTrainer(
    model=model,
    train_dataset=dataset["train"],
    eval_dataset=dataset["validation"],
    peft_config=peft_config,
    dataset_text_field=None, # We use formatting func below
    max_seq_length=2048,     # As per your strategy
    tokenizer=tokenizer,
    args=training_args,
    formatting_func=lambda example: [
        f"### Instruction:\n{inst}\n\n### Input:\n{inp}\n\n### Response:\n{out}"
        for inst, inp, out in zip(example['instruction'], example['input'], example['output'])
    ]
)

# 9. Train and Save
print("Starting training...")
trainer.train()
trainer.model.save_pretrained(new_model_name)
print(f"Model saved to {new_model_name}")
